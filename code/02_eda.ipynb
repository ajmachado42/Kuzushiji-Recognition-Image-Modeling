# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_raw = pd.read_csv('../data/train_clean.csv')
train_df = train_raw.copy()

# %%
train_df.head()
# Out:
#    label_id           image_id     Uni    W   H     X     Y
# 0         1  100241706_00004_2  U+306F  133  53  1231  3465
# 1         2  100241706_00004_2  U+304C   84  69   275  1652
# 2         3  100241706_00004_2  U+3044  143  69  1495  1218
# 3         4  100241706_00004_2  U+3051   53  91   220  3331
# 4         5  100241706_00004_2  U+306B   61  92   911  1452

# %%
train_df['W'].hist()
# Out:
# <AxesSubplot:>

# %%
train_df['H'].hist()
# Out:
# <AxesSubplot:>

# %%
# https://www.kaggle.com/code/diamondsnake/kuzushiji-recognition-faster-r-cnn
fig = plt.figure()

# read and plot the image
top_image = plt.imread('../data/train_images/100241706_00004_2.jpg')
plt.imshow(top_image);
